# %%
x = 5
y = 4
x + y
# Out:
# 9

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp311-cp311-macosx_10_12_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 12.1 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-macosx_10_9_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 12.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.7 MB/s eta 0:00:00
# Collecting numpy>=1.19
#   Downloading numpy-1.24.1-cp311-cp311-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 14.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /Users/pavelvatsek/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-2-cp311-cp311-macosx_10_10_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pavelvatsek/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/pavelvatsek/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 numpy-1.24.1 pillow-9.4.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt

x=[x for x in range(-100, 100)]
y=[t**3 for t in x]
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt
import math

def f(x) ->float:
        return math.sin()

x=[x for x in range(-10, 10)]
y=[math.sin(t) for t in x]
plt.plot(x,y)

# %%
def f(x):
  return math.sin(x) 
 
x=[x/100 for x in range(-314,314)] # список 
y=[f(t) for t in x]
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt
import math

def f(x):
  return 5*x*x-4*x-50 
 
x=[x/100 for x in range(-914,914)] # список 
y=[f(t) for t in x]
plt.plot(x,y)

# %%
# %pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 3.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.2.1 sympy-1.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy import *
from sympy.plotting import plot

# %%
x = 5
y = 4
plot(x, y)

# %%
x = symbols('x')
p1 = plot(x*x -5*x, show = false)
p2 = plot(5*x, show = false)
p1.append(p2[0])
p1.show()

# %%
x = symbols('x')
p1 = plot(-12*x*x*x*x*sin(cos(x)) - 18*x*x*x+5*x*x + 10*x - 30, show = false)
p2 = plot(5*x, show = false)
p1.append(p2[0])
p1.show()

# %%
x = symbols('x')
p1 = plot(x*x, show = False)
p2 = plot(32*(-x)**0.5, show = False)
p3 = plot(-32*x**0.5, show = False)
p4 = plot(-32*(-x)**0.5, show = False)
p5 = plot(32*x**0.5, show = False)
p6 = plot(-(x*x), show = False)
p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])
p1.append(p5[0])
p1.append(p6[0])
p1.show()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
from sympy import symbols,sin,cos
from sympy.plotting import plot,plot3d


x = symbols('x')
plot3d(x-12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x - 30,line_color = "purple")
p1 = plot3d(x*x, show = False)
p2 = plot3d(32*(-x)**0.5, show = False)
p3 = plot3d(-32*x**0.5, show = False)
p4 = plot3d(-32*(-x)**0.5, show = False)
p5 = plot3d(32*x**0.5, show = False)
p6 = plot3d(-(x*x), show = False)
p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])
p1.append(p5[0])
p1.append(p6[0])
p1.show()
